# %% [markdown]
# Version 9
# Dated 17 Oct.
#
# In this version we have removed the extra spaces, new lines so that we can save the columns in a pipe | delimited format with extention .txt.
# Also corrected the duplicate links that were fetched from the results page.

# %%
# import libraries
#import urllib2
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# specify the url
#quote_page = 'http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=0&p=1&f=S&l=50&Query=python%0D%0Aand%0D%0AISD%2F1%2F1%2F1995-%3E1%2F31%2F1999%0D%0A&d=PTXT'
quote_page = 'http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=0&p=2&f=S&l=50&Query=ACLM%2Fpython+&d=PTXT'
#quote_page='https://www.theice.com/marketdata/reports/173'

# %%
# query the website and return the html to the variable ‘page’
page = urlopen(quote_page)

# %%
# parse the html using beautiful soap and store in variable `soup`
soup = BeautifulSoup(page, 'html.parser')

# %%
# Take out the <div> of name and get its value
name_box = soup.find('h1', attrs={'class': 'name'})

# %% [markdown]
# soup

# %%
soup
# Out:
# <html>
# <head>
# <base target="_top"/>
# <title>Patent Database Search Results: ACLM/python in US Patent Collection</title>
# <script language="javascript">
# var clicked = false;
# // Shamelessly adapted from http://www.randomsnippets.com/2008/02/21/how-to-dynamically-add-form-elements-via-javascript/ 09-04-14. jh
# function addInput(divName,btnName,btnLabel) {
#    var newdiv = document.createElement('div');
#    newdiv.innerHTML = "<input type='hidden' name='" + btnName +
# 			"' value='" + btnLabel + "'>";
#    divName.appendChild(newdiv);
# }
# // -- 09-04-14.
# function check(form1,formBtn) {
#    // if submitted by <enter> key, add a submit button lookalike to prevent
#    // 1003 errs from BRS. 9-4-14 jh
#    if (!clicked)
#       addInput (form1,formBtn.name,formBtn.value);
#    return true;
# }
# function unesc(){
#    srchForm.Srch1.value = unescape(srchForm.Srch1.value);
#    if (srchForm.Srch2)
#       srchForm.Srch2.value = unescape(srchForm.Srch2.value);
# }
# ...

# %%
s = soup.text

def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

def find_between_r( s, first, last ):
    try:
        start = s.rindex( first ) + len( first )
        end = s.rindex( last, start )
        return s[start:end]
    except ValueError:
        return ""


print (find_between( s, "What is claimed is:", "* * * * *" ))
print (find_between_r (s, '123', 'abc' ))

# %%
for link in soup.find_all('a', href=True):
    #print 'http://patft.uspto.gov'+link['href']
    x =  link['href']
    print (link)
    #!/usr/bin/python
    if x[:19]=='/publicdocs/':
        print ('https://www.theice.com/marketdata/reports/173'+x )
# Out:
# <a href="/netahtml/PTO/index.html"><img alt="[Home]" border="0" src="/netaicon/PTO/home.gif"/></a>
# <a href="/netahtml/PTO/search-bool.html"><img alt="[Boolean Search]" border="0" src="/netaicon/PTO/boolean.gif"/></a>
# <a href="/netahtml/PTO/search-adv.htm"><img alt="[Manual Search]" border="0" src="/netaicon/PTO/manual.gif"/></a>
# <a href="/netahtml/PTO/srchnum.htm"><img alt="[Number Search]" border="0" src="/netaicon/PTO/number.gif"/></a>
# <a href="/netahtml/PTO/help/help.htm"><img alt="[Help]" border="0" src="/netaicon/PTO/help.gif"/></a>
# <a href="/netacgi/nph-Parser?Sect1=PTO2&amp;Sect2=HITOFF&amp;u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&amp;r=0&amp;p=1&amp;f=S&amp;l=50&amp;d=PTXT&amp;S1=(python.CLTX.+or+python.DCTX.)&amp;Page=Prev&amp;OS=ACLM/python&amp;RS=ACLM/python"><img align="MIDDLE" alt="[PREV_LIST]" border="0" src="/netaicon/PTO/prevlist.gif"/></a>
# ...

# %%
alllinks = []
count = 0 
for link in soup.find_all('a', href=True):
    #print 'http://patft.uspto.gov'+link['href']
    x =  link['href']
    #y= link['href']
    #!/usr/bin/python
    if x[:19]=='/netacgi/nph-Parser' and x.find('Next') == -1: #x.find('Query=PN'):
        print ('http://patft.uspto.gov'+x )
        #print (x.find('Query=PN'))
        print (count)
        count = count+1
        alllinks.append ('http://patft.uspto.gov'+x)
# Out:
# http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=0&p=1&f=S&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&Page=Prev&OS=ACLM/python&RS=ACLM/python
# 0
# http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=51&p=2&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python
# 1
# http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=51&p=2&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python
# 2
# http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=52&p=2&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python
# 3
# http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=52&p=2&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python
# 4
# ...

# %%
def remove_duplicates(l):
    return list(set(l))

# %%
alllinks = remove_duplicates(alllinks)

print (len(alllinks))
# Out:
# 51

# %%
from urllib.parse import urlparse
o = urlparse(alllinks[0])
o.geturl()
#alllinks
# Out:
# 'http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=63&p=2&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python'

# %%
quote_page2 = 'http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=1&p=1&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python/'
page2 = urlopen(quote_page2)

soup = BeautifulSoup(page2, 'html.parser')

#Paragraph for abstract https://chrisalbon.com/python/beautiful_soup_html_basics.html
headingline = soup.find('font', {'size':'+1'}).text
headingline = headingline.replace("\n", "")
print (headingline)

abstractline = soup.p.text
abstractline = abstractline.replace("\n", "")


print (abstractline)

line = find_between( soup.text, "What is claimed is:", "* * * * *" )
line = line.replace("\n", "")

line = ' '.join(line.split())

print (line)
#print soup
# Out:
# System and method for network configuration
#  One embodiment of the present invention provides a network device that     facilitates configuration orchestration. During operation, the system     interprets a configuration command and stores a data structure     representing a set of business logic. The business logic can be triggered     by the configuration command, a local condition, or both. Furthermore,     the system configures the switch according to an outcome of the business     logic.
# ...

# %%
def changeme( mylist ):
   "This changes a passed list into this function"
   mylist.append([1,2,3,4]);
   print ("Values inside the function: ", mylist)
   return

# Now you can call changeme function
mylist = [10,20,30];
changeme( mylist );
print ("Values outside the function: ", mylist)
# Out:
# Values inside the function:  [10, 20, 30, [1, 2, 3, 4]]
# Values outside the function:  [10, 20, 30, [1, 2, 3, 4]]

# %%
def getdatafromlink(link, lstofp):
    from urllib.request import urlopen
    from bs4 import BeautifulSoup
    #quote_page2 = 'http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=1&p=1&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python/'
    quote_page2 = link
    page2 = urlopen(quote_page2)

    soupinfun = BeautifulSoup(page2, 'html.parser')
    
    #lstofp = []
    #Paragraph for abstract https://chrisalbon.com/python/beautiful_soup_html_basics.html
    #print (soup)
    heading= (soupinfun.find('font', {'size':'+1'}).text).replace("\n", "")
    heading = ' '.join(heading.split())
    abstract= (soupinfun.p.text).replace("\n", "")
    abstract = ' '.join(abstract.split())
    claims = (find_between (soupinfun.text, 'What is claimed is:', '* * * * *' )).replace("\n", "")
    claims = ' '.join(claims.split())
    #print soup
    lstofp.append([link,heading, abstract, claims])
    page2.close()
    
    return lstofp;



#getdatafromlink ('http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=1&p=1&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python/')
alllinks[1]
#getdatafromlink('http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=1&p=1&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python/')
#getdatafromlink (alllinks[4])
# Out:
# 'http://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO2&Sect2=HITOFF&u=%2Fnetahtml%2FPTO%2Fsearch-adv.htm&r=53&p=2&f=G&l=50&d=PTXT&S1=(python.CLTX.+or+python.DCTX.)&OS=ACLM/python&RS=ACLM/python'

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e51f5dd68a05> in <module>()
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
listofp =[]
for item in alllinks:
    #print (item)
    listofp = getdatafromlink(item,listofp)

listofp

cols = ['Link', 'Heading', 'Abstract', 'Claims']

df1 = pd.DataFrame(listofp, columns=cols)

#print (df1)
df1.to_csv('output.txt', sep='|')

#df1['Claims']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-826be308fcf0> in <module>()
#       2 for item in alllinks:
#       3     #print (item)
# ----> 4     listofp = getdatafromlink(item,listofp)
#       5
#       6 listofp
#
# <ipython-input-31-cb86de552124> in getdatafromlink(link, lstofp)
#      11     #Paragraph for abstract https://chrisalbon.com/python/beautiful_soup_html_basics.html
#      12     #print (soup)
# ---> 13     heading= (soupinfun.find('font', {'size':'+1'}).text).replace("\n", "")
#      14     heading = ' '.join(heading.split())
#      15     abstract= (soupinfun.p.text).replace("\n", "")
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for eachitem in alllinks:
                getdatafromlink(eachitem)

# %%
len(alllinks)

# %%
import pandas as pd
cols = ['Link', 'Heading', 'Abstract', 'Details']
lst = []
for a in range(2):
    lst.append([1, 2, 3])
df1 = pd.DataFrame(lst, columns=cols)
df1

# %%
#https://www.quora.com/How-do-I-connect-cPanel-phpMyAdmin-database-using-Python
import pymysql
 
connection = pymysql.connect(  
                      host='indoisraelresearch.com.mysql',
                      #host = '10.27.22.48',
                      #port = '3306', 
                      user='indoisraelresea',
                      password='vinod@gami123456',
                      db='indoisraelresea',
                      charset='utf8mb4',
                      #unix_socket="/tmp/mysql.sock",
                      cursorclass=pymysql.cursors.DictCursor)
 
cursor = connection.cursor()
 
# Selecting.
query = "SELECT `id` FROM `table` ORDER BY RAND() LIMIT 1"
cursor.execute(query)
 
if cursor.rowcount == 0:
    print ('No results matched your query.')
else:
    print (cursor.fetchone()['id'])

# %%
import MySQLdb
